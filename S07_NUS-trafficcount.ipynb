# %% [markdown]
# # Define parameters

# %%
from traffic_events_peaks import *

# ####################
# Defind parameters
# ####################

project_par = {
    'data_input_path'   :   '../Singapore_data/phase7/new/',
    'data_output_path'  :  './S07_dA_peaks',
    'fig_output_path'   :  './OutFigs',
    'stations'          :  {'S07':['1806']},
#     'stations'          :  {'S07':['2225']},#phase 1:1806; phase 2:2225
    'components'        :  ['Z'],
    
    'verbosity'         :  True,
    'local_timezone'    :  True,  # correct time zone to local time
#     'proj_time_bgn'     :  UTCDateTime(2020,4,19,0,0,0),   # section begin time
#     'proj_time_end'     :  UTCDateTime(2020,4,22,0,59,59), # section end time
    
}

processing_par = {

    # remove response
    'remove_response'   : False,
    'remove_singlef'    : False,
    
    # resampling
    'downsampling_rate' : 0.002,
    
    # highpass filter
    'freq_highpass'     : 0.1,

    # PSD
    'PSD_winlen'        : 24*3600, # second, time length for output PSD
    
    # identify footsteps
    'winlen_spc'        : 3600,  # sec, time window length for calculating spectrogram
    'winlen_events'     : 24*3600, # sec, time window length for counting events
    'sampleRate'        : 500,
    'notch_freq'        : 50,
    'qality_factor'     : 100,
    'sel_lfre'          : 30,
    'sel_hfre'          : 150,
    'prominence'        : 5,#5
    'distance'          : 8,
    'alp'               : 3,
    't_h'               : 15,
    'c0'                : 1,
    'd_ind'             : 6,#5###############dind=6
    'f_l'               : 20,
    'f_h'               : 80,
    'mu'                : 5,
    'std_h'             : 1.5,
    'vcar'              : 11.1,
    'vs'                : 180,
    'delta_t1'          : 8*3600,#p1new,p2new 5*3600,p3new 1.5*3600, p4new,2*3600+2400,p5new,13*3600, p6new,p7new 8*3600
    'delta_t2'          : 24*3600,
    'nfft'              : 256,
    'nperseg'           : 256,
    'noverlap'          : 128,
    'pk_pct'            : 0.7,#################pk_pct=08
    }

# %% [markdown]
# # Processing flow

# %%
# ######################
# Data processing flow
# ######################
# %matplotlib inline


# initial DataProcessing class
dp = DataProcessing(project_par, processing_par, default_par)    

# get data list
dp.getdatalist()

for files in dp.data_list:
    
    dp.readdata(files)
    dp.preprocessing()
#     dp.high_pass()
    #dp.psd()
    dp.iso_traffic()
    
plt.close()
# Out:
# >>> Create input data_list and station_list!
# ../Singapore_data/phase7/new/453001806..0.16.2020.10.17.08.00.00.000.Z.sac
# ../Singapore_data/phase7/new/453001806..0.12.2020.10.13.08.00.00.000.Z.sac
# ../Singapore_data/phase7/new/453001806..0.2.2020.09.29.08.00.00.000.Z.sac
# ../Singapore_data/phase7/new/453001806..0.0.2020.09.30.08.00.00.000.Z.sac
# ../Singapore_data/phase7/new/453001806..0.3.2020.10.04.08.00.00.000.Z.sac
# ../Singapore_data/phase7/new/453001806..0.7.2020.10.08.08.00.00.000.Z.sac
# ../Singapore_data/phase7/new/453001806..0.20.2020.10.21.08.00.00.000.Z.sac
# ../Singapore_data/phase7/new/453001806..0.2.2020.10.03.08.00.00.000.Z.sac
# ../Singapore_data/phase7/new/453001806..0.15.2020.10.16.08.00.00.000.Z.sac
# ../Singapore_data/phase7/new/453001806..0.19.2020.10.20.08.00.00.000.Z.sac
# ../Singapore_data/phase7/new/453001806..0.17.2020.10.18.08.00.00.000.Z.sac
# ../Singapore_data/phase7/new/453001806..0.4.2020.10.05.08.00.00.000.Z.sac
# ../Singapore_data/phase7/new/453001806..0.0.2020.09.27.12.37.42.000.Z.sac
# ../Singapore_data/phase7/new/453001806..0.8.2020.10.09.08.00.00.000.Z.sac
# ../Singapore_data/phase7/new/453001806..0.1.2020.10.02.08.00.00.000.Z.sac
# ../Singapore_data/phase7/new/453001806..0.9.2020.10.10.08.00.00.000.Z.sac
# ../Singapore_data/phase7/new/453001806..0.18.2020.10.19.08.00.00.000.Z.sac
# ../Singapore_data/phase7/new/453001806..0.0.2020.10.01.08.00.00.000.Z.sac
# ../Singapore_data/phase7/new/453001806..0.5.2020.10.06.08.00.00.000.Z.sac
# ../Singapore_data/phase7/new/453001806..0.6.2020.10.07.08.00.00.000.Z.sac
# ../Singapore_data/phase7/new/453001806..0.13.2020.10.14.08.00.00.000.Z.sac
# ../Singapore_data/phase7/new/453001806..0.14.2020.10.15.08.00.00.000.Z.sac
# ../Singapore_data/phase7/new/453001806..0.1.2020.09.28.08.00.00.000.Z.sac
# ../Singapore_data/phase7/new/453001806..0.11.2020.10.12.08.00.00.000.Z.sac
# ../Singapore_data/phase7/new/453001806..0.10.2020.10.11.08.00.00.000.Z.sac
#  >>> Read data from ../Singapore_data/phase7/new/453001806..0.16.2020.10.17.08.00.00.000.Z.sac
# 1 Trace(s) in Stream:
# .3001806..Z | 2020-10-17T08:00:00.000000Z - 2020-10-19T08:00:00.004547Z | 500.0 Hz, 86399998 samples
#  Pre-processing:  correct time-zone
# 1 Trace(s) in Stream:
# S07.3001806..Z | 2020-10-17T16:00:00.000000Z - 2020-10-19T16:00:00.004547Z | 500.0 Hz, 86399998 samples
#  >>> Read data from ../Singapore_data/phase7/new/453001806..0.12.2020.10.13.08.00.00.000.Z.sac
# 1 Trace(s) in Stream:
# .3001806..Z | 2020-10-13T08:00:00.000000Z - 2020-10-15T08:00:00.004547Z | 500.0 Hz, 86399998 samples
#  Pre-processing:  correct time-zone
# 1 Trace(s) in Stream:
# S07.3001806..Z | 2020-10-13T16:00:00.000000Z - 2020-10-15T16:00:00.004547Z | 500.0 Hz, 86399998 samples
#  >>> Read data from ../Singapore_data/phase7/new/453001806..0.2.2020.09.29.08.00.00.000.Z.sac
# 1 Trace(s) in Stream:
# .3001806..Z | 2020-09-29T08:00:00.000000Z - 2020-10-01T08:00:00.004547Z | 500.0 Hz, 86399998 samples
#  Pre-processing:  correct time-zone
# 1 Trace(s) in Stream:
# S07.3001806..Z | 2020